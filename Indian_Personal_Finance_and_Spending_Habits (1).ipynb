# %%
import pandas as pd

# %%
Df=pd.read_csv('/content/Indian Personal Finance and Spending Habits.csv')

# %%
Df.sample(10)
# Out:
#               Income  Age  Dependents     Occupation City_Tier          Rent  \
# 12050   70916.974900   30           3   Professional    Tier_2  14183.394980
# 10021   48641.414719   45           1        Retired    Tier_2   9728.282944
# 10063  124779.129557   34           1        Student    Tier_2  24955.825911
# 15002   31583.451115   58           2   Professional    Tier_2   6316.690223
# 18578   88860.753601   55           0        Retired    Tier_3  13329.113040
# 10898   17454.341953   63           3   Professional    Tier_2   3490.868391
# 16667   29237.397347   62           4        Student    Tier_3   4385.609602
# 11963   13587.991307   41           1   Professional    Tier_1   4076.397392
# 5614    19933.585954   47           3  Self_Employed    Tier_3   2990.037893
# 2519    15181.418824   42           4        Student    Tier_3   2277.212824
#
#        Loan_Repayment    Insurance     Groceries    Transport  ...  \
# ...

# %%
Df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 27 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Income                           20000 non-null  float64
#  1   Age                              20000 non-null  int64
#  2   Dependents                       20000 non-null  int64
#  3   Occupation                       20000 non-null  object
#  4   City_Tier                        20000 non-null  object
#  5   Rent                             20000 non-null  float64
#  6   Loan_Repayment                   20000 non-null  float64
#  7   Insurance                        20000 non-null  float64
#  8   Groceries                        20000 non-null  float64
#  9   Transport                        20000 non-null  float64
#  10  Eating_Out                       20000 non-null  float64
# ...

# %%
Df.describe
# Out:
# <bound method NDFrame.describe of               Income  Age  Dependents     Occupation City_Tier          Rent  \
# 0       44637.249636   49           0  Self_Employed    Tier_1  13391.174891
# 1       26858.596592   34           2        Retired    Tier_2   5371.719318
# 2       50367.605084   35           1        Student    Tier_3   7555.140763
# 3      101455.600247   21           0  Self_Employed    Tier_3  15218.340037
# 4       24875.283548   52           4   Professional    Tier_2   4975.056710
# ...              ...  ...         ...            ...       ...           ...
# 19995   40913.466178   51           4  Self_Employed    Tier_1  12274.039853
# 19996   90295.772638   21           1        Student    Tier_2  18059.154528
# 19997   40604.567373   30           1   Professional    Tier_2   8120.913475
# 19998  118157.817240   27           2   Professional    Tier_1  35447.345172
# 19999    8209.249769   62           3   Professional    Tier_1   2462.774931
#
# ...

# %%
Df.isnull().sum()
# Out:
# Income                             0
# Age                                0
# Dependents                         0
# Occupation                         0
# City_Tier                          0
# Rent                               0
# Loan_Repayment                     0
# Insurance                          0
# Groceries                          0
# Transport                          0
# Eating_Out                         0
# Entertainment                      0
# Utilities                          0
# Healthcare                         0
# Education                          0
# Miscellaneous                      0
# Desired_Savings_Percentage         0
# Desired_Savings                    0
# Disposable_Income                  0
# Potential_Savings_Groceries        0
# Potential_Savings_Transport        0
# Potential_Savings_Eating_Out       0
# Potential_Savings_Entertainment    0
# Potential_Savings_Utilities        0
# Potential_Savings_Healthcare       0
# ...

# %% [markdown]
# *remove null values*

# %%
# Remove columns that contain any null values
Df_cleaned = Df.dropna(axis=1, how='any')

# If you want to remove columns where all values are null
Df_cleaned = Df.dropna(axis=1, how='all')

# In-place removal (modifies the original dataframe)
Df.dropna(axis=1, inplace=True)

# %% [markdown]
# *Count the non null values*

# %%
# Get count of non-null values for each column
non_null_counts = Df.count()
print(non_null_counts)
# Out:
# Income                             20000
# Age                                20000
# Dependents                         20000
# Occupation                         20000
# City_Tier                          20000
# Rent                               20000
# Loan_Repayment                     20000
# Insurance                          20000
# Groceries                          20000
# Transport                          20000
# Eating_Out                         20000
# Entertainment                      20000
# Utilities                          20000
# Healthcare                         20000
# Education                          20000
# Miscellaneous                      20000
# Desired_Savings_Percentage         20000
# Desired_Savings                    20000
# Disposable_Income                  20000
# Potential_Savings_Groceries        20000
# Potential_Savings_Transport        20000
# Potential_Savings_Eating_Out       20000
# Potential_Savings_Entertainment    20000
# ...

# %% [markdown]
# *remove the duplicate*

# %%
# Remove duplicates based on specific columns (e.g., 'col1' and 'col2')
Df_cleaned = Df.drop_duplicates(subset=['Income', 'Age','Dependents','Occupation','City_Tier','Rent','Loan_Repayment','Insurance','Groceries','Transport','Eating_Out','Entertainment','Utilities','Healthcare','Education','Miscellaneous','Desired_Savings_Percentage','Desired_Savings','Disposable_Income','Potential_Savings_Groceries','Potential_Savings_Transport','Potential_Savings_Eating_Out','Potential_Savings_Entertainment','Potential_Savings_Utilities','Potential_Savings_Healthcare','Potential_Savings_Education','Potential_Savings_Miscellaneous'])

# In-place removal (modifies the original DataFrame)
Df.drop_duplicates(subset=['Income', 'Age','Dependents','Occupation','City_Tier','Rent','Loan_Repayment','Insurance','Groceries','Transport','Eating_Out','Entertainment','Utilities','Healthcare','Education','Miscellaneous','Desired_Savings_Percentage','Desired_Savings','Disposable_Income','Potential_Savings_Groceries','Potential_Savings_Transport','Potential_Savings_Eating_Out','Potential_Savings_Entertainment','Potential_Savings_Utilities','Potential_Savings_Healthcare','Potential_Savings_Education','Potential_Savings_Miscellaneous'], inplace=True)

# Check the shape after removing duplicates
print(f"Rows after removing duplicates based on specific columns: {Df.shape[0]}")
# Out:
# Rows after removing duplicates based on specific columns: 20000

# %% [markdown]
# *Counting Rows and Columns*

# %%
num_rows, num_columns = Df.shape

print(f'Number of rows: {num_rows}')
print(f'Number of columns: {num_columns}')
# Out:
# Number of rows: 20000
# Number of columns: 27

# %%
Df['Disposable_Income'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        11265.627707
# 1         9676.818733
# 2        13891.450624
# 3        31617.953615
# 4         6265.700532
#              ...
# 19995     1163.318310
# 19996    30725.175170
# 19997     2267.905134
# 19998    10603.684814
# 19999      860.350559
# Name: Disposable_Income, Length: 20000, dtype: float64>

# %%
Df.shape
# Out:
# (20000, 27)
